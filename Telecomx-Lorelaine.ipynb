# %%
# 🎯 Churn - Distribuição
# Add checks before plotting
print("Value counts for 'Churn':")
print(df['Churn'].value_counts())
print("\nData type of 'Churn':", df['Churn'].dtype)
print("-" * 20)

sns.countplot(data=df, x='Churn')
plt.title("Distribuição de Evasão de Clientes (Churn)")
plt.show()

# 📄 Tipo de contrato x Churn
# Add checks before plotting
print("Value counts for 'Contract':")
print(df['Contract'].value_counts())
print("\nData type of 'Contract':", df['Contract'].dtype)
print("-" * 20)

sns.countplot(data=df, x='Contract', hue='Churn')
plt.title("Churn por Tipo de Contrato")
plt.xticks(rotation=45)
plt.show()

# 💰 Gastos mensais x Churn
# Add checks before plotting
print("Description of 'Charges_Monthly':")
print(df['Charges_Monthly'].describe())
print("\nData type of 'Charges_Monthly':", df['Charges_Monthly'].dtype)
print("-" * 20)

sns.boxplot(data=df, x='Churn', y='Charges_Monthly')
plt.title("Distribuição dos Gastos Mensais por Churn")
plt.show()
# Out:
# Value counts for 'Churn':
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
#
# Data type of 'Churn': object
# --------------------
# Value counts for 'Contract':
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64
#
# Data type of 'Contract': object
# --------------------
# Description of 'Charges_Monthly':
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: Charges_Monthly, dtype: float64
#
# Data type of 'Charges_Monthly': float64
# --------------------

# %%
# 🎯 Churn - Distribuição
sns.countplot(data=df, x='Churn')
plt.title("Distribuição de Evasão de Clientes (Churn)")
plt.show()

# 📄 Tipo de contrato x Churn
sns.countplot(data=df, x='Contract', hue='Churn')
plt.title("Churn por Tipo de Contrato")
plt.xticks(rotation=45)
plt.show()

# 💰 Gastos mensais x Churn
sns.boxplot(data=df, x='Churn', y='Charges_Monthly')
plt.title("Distribuição dos Gastos Mensais por Churn")
plt.show()
